# %% [markdown]
# # List SharePoint Folders with Azure Default Credential
#
# This notebook demonstrates how to use Azure Default Credential to authenticate with Microsoft Graph and list folders in a SharePoint folder.

# %%
from azure.identity import DefaultAzureCredential
from corvus_python.sharepoint.sharepoint_utils import SharePointUtilities
from corvus_python.auth import get_az_cli_token

# %% [markdown]
# ## Get Microsoft Graph Token

# %%
graph_token = get_az_cli_token('https://graph.microsoft.com/.default')

# %% [markdown]
# ## List Folders in a SharePoint Folder
#
# Set your SharePoint drive ID and folder path, then list the folders using Microsoft Graph.

# %%
SHAREPOINT_TENANT = "endjin.sharepoint.com"
SHAREPOINT_SITE = "<SITE_NAME>"
LIBRARY_NAME = "Shared%20Documents"
FOLDER_PATH = "<FOLDER_PATH>"
headers = {
    "Accept": "application/json",
    "Content-Type": "application/json; charset=utf-8",
    "Authorization": f"Bearer {graph_token}",
}

# Get drive ID using SharePointUtilities
DRIVE_ID = SharePointUtilities.get_drive_id(SHAREPOINT_TENANT, SHAREPOINT_SITE, LIBRARY_NAME, headers)

# Use SharePointUtilities to list folders in the specified folder
folders = SharePointUtilities.get_folders_in_folder(DRIVE_ID, FOLDER_PATH, graph_token)
folders
# Out:
# [{'@odata.etag': '"{6956DABE-8403-4ACF-8F94-DB69C6D2BB80},4"',
#   'id': '0156F6YRN63JLGSA4EZ5FI7FG3NHDNFO4A',
#   'name': 'AAM',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/AAM',
#   'folder': {'childCount': 6}},
#  {'@odata.etag': '"{FB3448D9-47A6-4C04-95C9-0DAB41BBD691},1"',
#   'id': '0156F6YROZJA2PXJSHARGJLSINVNA3XVUR',
#   'name': 'AI',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/AI',
#   'folder': {'childCount': 2}},
#  {'@odata.etag': '"{BD5484EB-EDE1-4033-AA9A-FEEB57A6E31D},3"',
#   'id': '0156F6YRPLQRKL3YPNGNAKVGX65NL2NYY5',
#   'name': 'Artefacts & templates',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Artefacts%20%26%20templates',
#   'folder': {'childCount': 7}},
#  {'@odata.etag': '"{B4069D2F-44E0-4980-8AB5-F8D599069900},3"',
#   'id': '0156F6YRJPTUDLJYCEQBEYVNPY2WMQNGIA',
#   'name': 'Azure Infra & Architecture',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Azure%20Infra%20%26%20Architecture',
#   'folder': {'childCount': 18}},
#  {'@odata.etag': '"{2C05ED30-F3B2-4044-AA59-4331D71DCB37},4"',
#   'id': '0156F6YRJQ5UCSZMXTIRAKUWKDGHLR3SZX',
#   'name': 'Community of Practice',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Community%20of%20Practice',
#   'folder': {'childCount': 2}},
#  {'@odata.etag': '"{1D6D5978-1EF9-482A-9E50-EB64F680332F},4"',
#   'id': '0156F6YRLYLFWR36I6FJEJ4UHLMT3IAMZP',
#   'name': 'Data Validation App',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Data%20Validation%20App',
#   'folder': {'childCount': 8}},
#  {'@odata.etag': '"{FCA62BF0-F5F2-4182-8AB5-2CC2D154FD6B},1"',
#   'id': '0156F6YRPQFOTPZ4XVQJAYVNJMYLIVJ7LL',
#   'name': 'Demand Management',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Demand%20Management',
#   'folder': {'childCount': 14}},
#  {'@odata.etag': '"{8CA06DBA-94E8-453D-8660-58C51A8D0B39},1"',
#   'id': '0156F6YRN2NWQIZ2EUHVCYMYCYYUNI2CZZ',
#   'name': 'EOW Updates',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/EOW%20Updates',
#   'folder': {'childCount': 9}},
#  {'@odata.etag': '"{88163E7F-ECB4-4F0E-BB0E-DAA33F7355AC},1"',
#   'id': '0156F6YRL7HYLIRNHMBZH3WDW2UM7XGVNM',
#   'name': 'Games Operations',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Games%20Operations',
#   'folder': {'childCount': 2}},
#  {'@odata.etag': '"{7703BA2A-EC08-4AC4-9D86-D383B1884044},1"',
#   'id': '0156F6YRJKXIBXOCHMYRFJ3BWTQOYYQQCE',
#   'name': 'Images Strategy',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Images%20Strategy',
#   'folder': {'childCount': 8}},
#  {'@odata.etag': '"{6CAFEF70-1B71-4EF6-B060-AE5B1C0E7384},4"',
#   'id': '0156F6YRLQ56XWY4I36ZHLAYFOLMOA444E',
#   'name': 'Market Research',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Market%20Research',
#   'folder': {'childCount': 56}},
#  {'@odata.etag': '"{B7592DA3-CBC9-4D86-A834-E8680C1E3E78},4"',
#   'id': '0156F6YRNDFVM3PSOLQZG2QNHINAGB4PTY',
#   'name': 'Master Data Management',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Master%20Data%20Management',
#   'folder': {'childCount': 22}},
#  {'@odata.etag': '"{A5B37906-AC46-4923-93CE-1AA344E43804},4"',
#   'id': '0156F6YRIGPGZ2KRVMENEZHTQ2UNCOIOAE',
#   'name': 'MERL',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/MERL',
#   'folder': {'childCount': 7}},
#  {'@odata.etag': '"{1A4C3BEE-7C67-4EDC-B0F4-09CF0AA8A932},4"',
#   'id': '0156F6YRPOHNGBUZ343RHLB5AJZ4FKRKJS',
#   'name': 'NOC Data',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/NOC%20Data',
#   'folder': {'childCount': 32}},
#  {'@odata.etag': '"{CB67B6A5-C163-4320-BC14-224569CAC645},4"',
#   'id': '0156F6YRNFWZT4WY6BEBB3YFBCIVU4VRSF',
#   'name': 'ODF',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/ODF',
#   'folder': {'childCount': 3}},
#  {'@odata.etag': '"{5E91819C-639D-407E-8783-97F4B1D273A9},4"',
#   'id': '0156F6YRM4QGIV5HLDPZAIPA4X6SY5E45J',
#   'name': 'ORF',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/ORF',
#   'folder': {'childCount': 1}},
#  {'@odata.etag': '"{8D31C2B2-F7B9-4BFD-816B-7EF985B65BC1},1"',
#   'id': '0156F6YRNSYIYY3OPX7VFYC2367GC3MW6B',
#   'name': 'Safe Sport',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Safe%20Sport',
#   'folder': {'childCount': 1}},
#  {'@odata.etag': '"{A24F999E-D118-4C6F-A55B-E8706520A545},1"',
#   'id': '0156F6YRM6TFH2EGGRN5GKKW7IOBSSBJKF',
#   'name': 'SDW',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/SDW',
#   'folder': {'childCount': 1}},
#  {'@odata.etag': '"{90B063CC-2B62-4D49-8E50-C39520292FCC},2"',
#   'id': '0156F6YROMMOYJAYRLJFGY4UGDSUQCSL6M',
#   'name': 'SEAT',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/SEAT',
#   'folder': {'childCount': 7}},
#  {'@odata.etag': '"{E881E973-860F-45D5-82C8-4EDADF857140},4"',
#   'id': '0156F6YRLT5GA6QD4G2VCYFSCO3LPYK4KA',
#   'name': 'Sports Popularity',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Sports%20Popularity',
#   'folder': {'childCount': 66}},
#  {'@odata.etag': '"{8A3C8FA9-26BF-480D-ABD1-BFAB30CFBCA8},1"',
#   'id': '0156F6YRNJR46IVPZGBVEKXUN7VMYM7PFI',
#   'name': 'Venue Legacy',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Venue%20Legacy',
#   'folder': {'childCount': 2}},
#  {'@odata.etag': '"{D6BC992C-A6BC-46CF-BC85-446DA62D674F},112"',
#   'id': '0156F6YRJMTG6NNPFGZ5DLZBKENWTC2Z2P',
#   'name': '15th May 2025.pptx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7BD6BC992C-A6BC-46CF-BC85-446DA62D674F%7D&file=15th%20May%202025.pptx&action=edit&mobileredirect=true'},
#  {'@odata.etag': '"{9B225A58-0656-49A4-9E1F-5337F6FDA049},11"',
#   'id': '0156F6YRKYLIRJWVQGUREZ4H2TG73P3ICJ',
#   'name': 'data validation app estimates.xlsx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7B9B225A58-0656-49A4-9E1F-5337F6FDA049%7D&file=data%20validation%20app%20estimates.xlsx&action=default&mobileredirect=true'},
#  {'@odata.etag': '"{98DF5250-FC05-441D-AA2E-EF5E149DD9C3},4"',
#   'id': '0156F6YRKQKLPZQBP4DVCKULXPLYKJ3WOD',
#   'name': 'EDAP - Security audit - report__Oct-2024.pdf',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/EDAP%20-%20Security%20audit%20-%20report__Oct-2024.pdf'},
#  {'@odata.etag': '"{44D4435C-DFD4-497B-B574-09E33A58C002},3"',
#   'id': '0156F6YRK4IPKEJVG7PNE3K5AJ4M5FRQAC',
#   'name': 'EDAP_Prisma__oct24.xlsx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7B44D4435C-DFD4-497B-B574-09E33A58C002%7D&file=EDAP_Prisma__oct24.xlsx&action=default&mobileredirect=true'},
#  {'@odata.etag': '"{B9BBEC49-DF8D-4E94-8D3D-28F63018F9FE},48"',
#   'id': '0156F6YRKJ5S53TDO7SRHI2PJI6YYBR6P6',
#   'name': 'edap-security-model-matrix - Insights & Analytics.xlsx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7BB9BBEC49-DF8D-4E94-8D3D-28F63018F9FE%7D&file=edap-security-model-matrix%20-%20Insights%20%26%20Analytics.xlsx&action=default&mobileredirect=true'},
#  {'@odata.etag': '"{0AFA4207-F5BF-435E-8921-1568810BD8DD},375"',
#   'id': '0156F6YRIHIL5AVP7VLZBYSIIVNCAQXWG5',
#   'name': 'edap-security-model-matrix.xlsx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7B0AFA4207-F5BF-435E-8921-1568810BD8DD%7D&file=edap-security-model-matrix.xlsx&action=default&mobileredirect=true'},
#  {'@odata.etag': '"{CE96FF14-805A-4250-85BA-707B191BB226},1"',
#   'id': '0156F6YRIU76LM4WUAKBBILOTQPMMRXMRG',
#   'name': 'Information Security - Information Classification Policy.pdf',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Information%20Security%20-%20Information%20Classification%20Policy.pdf'},
#  {'@odata.etag': '"{28E8A097-DF90-4FE1-838C-C8F55F2009BD},2"',
#   'id': '0156F6YRMXUDUCREG74FHYHDGI6VPSACN5',
#   'name': 'Org chart.xmind',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/Shared%20Documents/09.%20EDAP/Org%20chart.xmind'},
#  {'@odata.etag': '"{EEA14E9A-7635-4914-A4D1-CF805CCE126A},17"',
#   'id': '0156F6YRM2J2Q64NLWCRE2JUOPQBOM4ETK',
#   'name': 'Service Management Objectives.docx',
#   'webUrl': 'https://endjin.sharepoint.com/sites/IOC/_layouts/15/Doc.aspx?sourcedoc=%7BEEA14E9A-7635-4914-A4D1-CF805CCE126A%7D&file=Service%20Management%20Objectives.docx&action=default&mobileredirect=true'}]
